# %%
import pandas as pd
import os

school_dropout_df = pd.read_csv('school_dropout.csv')
school_dropout_df.index.name = "ID"
school_dropout_df.head()
# Out:
#     Marital status  Application mode  Application order  Course  \
# ID
# 0                1                 8                  5       2
# 1                1                 6                  1      11
# 2                1                 1                  5       5
# 3                1                 8                  2      15
# 4                2                12                  1       3
#
#     Daytime/evening attendance  Previous qualification  Nacionality  \
# ID
# 0                            1                       1            1
# 1                            1                       1            1
# 2                            1                       1            1
# 3                            1                       1            1
# 4                            0                       1            1
#
#     Mother's qualification  Father's qualification  Mother's occupation  ...  \
# ID                                                                       ...
# ...

# %%
#Confirm type of data
school_dropout_df.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# Tuition fees up to date                             int64
# Gender                                              int64
# ...

# %%
#Create both tables and print table 1
school_dropout_clean1_df = school_dropout_df[['Marital status','Nacionality','Application mode','Course','Previous qualification',"Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Gender","Daytime/evening attendance","Target"]]

school_dropout_clean1_df.head()
# Out:
#     Marital status  Nacionality  Application mode  Course  \
# ID
# 0                1            1                 8       2
# 1                1            1                 6      11
# 2                1            1                 1       5
# 3                1            1                 8      15
# 4                2            1                12       3
#
#     Previous qualification  Mother's qualification  Father's qualification  \
# ID
# 0                        1                      13                      10
# 1                        1                       1                       3
# 2                        1                      22                      27
# 3                        1                      23                      27
# 4                        1                      22                      28
#
#     Mother's occupation  Father's occupation  Gender  \
# ID
# 0                     6                   10       1
# ...

# %%
#Keeping Drop
clean_data_df = school_dropout_clean1_df.loc[
      (school_dropout_clean1_df["Target"] != "Enrolled")
]
clean_data_df.head()
# Out:
#     Marital status  Nacionality  Application mode  Course  \
# ID
# 0                1            1                 8       2
# 1                1            1                 6      11
# 2                1            1                 1       5
# 3                1            1                 8      15
# 4                2            1                12       3
#
#     Previous qualification  Mother's qualification  Father's qualification  \
# ID
# 0                        1                      13                      10
# 1                        1                       1                       3
# 2                        1                      22                      27
# 3                        1                      23                      27
# 4                        1                      22                      28
#
#     Mother's occupation  Father's occupation  Gender  \
# ID
# 0                     6                   10       1
# ...

# %%
clean_data1_df = clean_data_df[["Mother's occupation","Father's occupation","Gender","Daytime/evening attendance","Target"]]
clean_data2_df = clean_data_df[['Marital status','Nacionality','Application mode','Course','Previous qualification',"Mother's qualification","Father's qualification"]]

# %%
clean_data1_df.head()
# Out:
#     Mother's occupation  Father's occupation  Gender  \
# ID
# 0                     6                   10       1
# 1                     4                    4       1
# 2                    10                   10       1
# 3                     6                    4       0
# 4                    10                   10       0
#
#     Daytime/evening attendance    Target
# ID
# 0                            1   Dropout
# 1                            1  Graduate
# 2                            1   Dropout
# 3                            1  Graduate
# 4                            0  Graduate

# %%
clean_data2_df.head()
# Out:
#     Marital status  Nacionality  Application mode  Course  \
# ID
# 0                1            1                 8       2
# 1                1            1                 6      11
# 2                1            1                 1       5
# 3                1            1                 8      15
# 4                2            1                12       3
#
#     Previous qualification  Mother's qualification  Father's qualification
# ID
# 0                        1                      13                      10
# 1                        1                       1                       3
# 2                        1                      22                      27
# 3                        1                      23                      27
# 4                        1                      22                      28

# %%
clean_data1_df = clean_data1_df.to_csv('clean_data1.csv')
clean_data2_df = clean_data2_df.to_csv('clean_data2.csv')
